# %% [markdown]
# **1**. **What is the difference between a function and a method in Python?**
#
# **Function**: Function is an independent block of code that performs a task and can be called by its name. Functions are typically independent.
#
# **Method**: Method is a functioon associated with an object and it operates on that object's data. So methods are Object-specific.

# %% [markdown]
# **2**. **Explain the concept of function arguments and parameters in Python.**
#
# **Parameters**:  It is the variable names listed in a function's definition.
#
# def greet(name):
#   print("hello ", name)
#
#   #here (name) is the parameter.
#
# **Arguments**: are the actual values passed to the function when it is called.
#
# greet("Ankit")

# %% [markdown]
# **3. What are the different ways to define and call a function in Python?**

# %%
# Standard function
def greet(name):
  print("hello", name)
greet("manish")

# Function with default arguments:
def greet(name="manish"):
  print("hello", name)
greet()
greet("Ram")

# Function with variable arguments:

def greet(*args):
  for name in args:
    print("hello", name)
greet("manish", "Ram", "Raj")

def add_all(*args):
  return sum(args)
print(add_all(1,2,3,4))

# lambda functon:
d = lambda x:x**2
print(d(4))
# Out:
# hello manish
# hello manish
# hello Ram
# hello manish
# hello Ram
# hello Raj
# 10
# 16

# %% [markdown]
# **4. What is the purpose of the `return` statement in a Python function?**
#
# The 'return' statement in Python is used to deliver a result. It ends the function's execution.
# - Example

# %%
def add(a,b):
  return a+b

result = add(3,4)
print(result)
# Out:
# 7

# %% [markdown]
# **5. What are iterators in Python and how do they differ from iterables?**
#
# - **Iterable:** Any python object that can loop over (like - list, tuple, dict, set, str). It implements the 'iter()' method.
#
# my_list = [1,2,3]
#
# - **Iterator:** An object that produces values one at a time using 'next()' and remembers where it left off. It's created from an iterable using 'iter()'.
#
# my_iter = iter(my_list)
# print(next(my_iter))
# print(next(my_iter))

# %% [markdown]
# **6. Explain the concept of generators in Python and how they are defined.**
#
# - **Generator:** a special type of iterator in Python that yields values one at a time using the 'yield' keyword instead of 'return'. It's memory-efficient way to produce large sequences without storing them all in memory.

# %%
def count_up_to(n):
    count = 1
    while count<= n:
        yield count
        count += 1

print(count_up_to(6))
for num in count_up_to(6):
    print(num, end=' ')
# Out:
# <generator object count_up_to at 0x7c9a85efac80>
# 1 2 3 4 5 6

# %% [markdown]
# **7. What are the advantages of using generators over regular functions?**
#
# - **Memory Efficiency :** Generators yield one items at a time instead of storing the entire result in memory.
# - **Improved Performance :** No need to compute all results upfront, which saves time and processing power.
# - **Lazy Evaluation :** Values are generated only when needed, which improves performance.

# %% [markdown]
# **8. What is a lambda function in Python and when is it typically used?**
#
# - **lambda Function** is an anonnymous, one-line function using 'lambda' keyword.
# - It is typically used for short, simple operations that don't require a full 'def' block.

# %%
square = lambda x: x**2
print(square(2))
# Out:
# 4

# %% [markdown]
# **9. Explain the purpose and usage of the `map()` function in Python.**
#
# The 'map()' function is used to apply a function to every item in an iterable(like a list or tuple) and return a new map object (an iterator) with the transformed values.

# %%
numbers = [1,2,3,4]
squares = map(lambda x: x**3, numbers)
print(list(squares))
# Out:
# [1, 8, 27, 64]

# %% [markdown]
# **10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**
#
# - **map:** Returns a new iterator by applying the given function to each item in the input iterable.

# %%
D = [1,2,3]
square = map(lambda x:x**2, D)
print(list(square))
# Out:
# [1, 4, 9]

# %% [markdown]
# **filter:** Returns a new iterator containing only those items from the iterable for which the function returns 'True'.

# %%
d = [1,2,3,4,5,6,7,8,9]
even = filter(lambda x:x%2 ==0, d)
print(list(even))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# **reduce:** Applies the function cumulatively to the items in the iterable, so as to reduce it to a single value.

# %%
from functools import reduce
D = [2,3,4,5,6,7,8,9]
sum = reduce(lambda x,y: x*y, D)
print(sum)
# Out:
# 362880

# %% [markdown]
# **11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];**

# %% [markdown]
# ![WhatsApp Image 2025-09-02 at 16.14.55_4f13bd08.jpg](data:image/jpeg;base64,...)
